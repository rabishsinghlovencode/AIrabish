# %%
alist = [34,67,23,65,26,37]
alist.append(90)        # adding single value

# %%
print("After appending:",alist)
alist.extend([84,19,84]) # adding multiple values
# Out:
# After appending: [34, 67, 23, 65, 26, 37, 90]

# %%
print("After extending:",alist)
alist.insert(1,16)
print("after inserting:",alist)
alist.pop(4) # 0 is the index - remove value at that index
print("After pop operation:",alist)
alist.remove(90)  # removing value directly
print("After removing:",alist)
alist.reverse()
print("After reversing:",alist)
alist.sort()
print("After sorting:",alist)
# Out:
# After extending: [34, 67, 23, 65, 26, 37, 90, 84, 19, 84]
# after inserting: [34, 16, 67, 23, 65, 26, 37, 90, 84, 19, 84]
# After pop operation: [34, 16, 67, 23, 26, 37, 90, 84, 19, 84]
# After removing: [34, 16, 67, 23, 26, 37, 84, 19, 84]
# After reversing: [84, 19, 84, 37, 26, 23, 67, 16, 34]
# After sorting: [16, 19, 23, 26, 34, 37, 67, 84, 84]
