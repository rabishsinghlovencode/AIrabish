# %%
import pandas as pd

# %%
#mysql | oracle | mongodb

df = pd.read_csv("empinfo.csv")

# %%
df

# %%
# display first 2 records
df.head()

# %%
# diplast last 3 records
df.tail(3)

# %%
output = df.head(10)
output.to_csv("finaloutput.csv",index=False)

# %%
# display count of rows and columns
df.shape

# %%
# display datatype of each column
df.dtypes

# %%
# info of hte dataframe
df.info()

# %%
# display all the unique workclasses
df['workclass'].unique()

# %%
# display the count of unique workclasses
df['workclass'].nunique()

# %%
# all unique workclasses and count of each workclass
df['workclass'].value_counts()

# %%
# sorting 
df.sort_values(by="age")

# %%
output = df.sort_values(by="age")
output.to_csv("sortedages.csv")

###### or #####
df.sort_values(by="age").to_csv("sorted_ages.csv")

# %%
#df.iloc[rows , columns ]
df.iloc[5:10]

# %%
df.iloc[5:10 , 0:4]

# %%
# sorting values in ascending order
df.sort_values(by = 'age')

# %%
# sorting values in ascending order
df.sort_values(by = 'age').to_csv("finaloutput1.csv")

# %%
#select * from table where workclass = 'private'

cond = df["workclass"] == " Private"

df[cond]

# %%
df[df["workclass"] == " Private"]

# %%
cond1 = df["workclass"] == " Private"
cond2 = df["gender"] == " Female"

df[cond1 & cond2]

# %%
#df[ (cond1) & (cond2) ]

df[ (df["workclass"] == " Private")  & (df["gender"] == " Female")]

# %%
# displays subset
df["workclass"]

# %%
df[['workclass','education','age']]

# %%
# handling missing values
# drop null values
df.dropna()

# %%
# fill null values with 0
df.fillna(0)
