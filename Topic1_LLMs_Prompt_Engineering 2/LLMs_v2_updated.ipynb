# %% [markdown]
# #Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # LLMs Lab-1

# %% [markdown]
# ## Code Generated through "prompts"

# %% [markdown]
# # Accessing OpenAI LLM through an API

# %%
#!pip install OpenAI
#!pip install langchain
#!pip install langchain_community
#!pip install Cohere


# !pip3 install -U langchain langchain-core langchain-community langchain-cohere langchain-openai python-dotenv

# %%
import os
os.environ['OPENAI_API_KEY'] = "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"
#os.environ['COHERE_API_KEY'] = "Your Key"

import warnings
warnings.filterwarnings('ignore')

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()


print(llm.invoke("How many minimum sleeping hours you should have?"))
# Out:
# content='Most adults need 7-9 hours of sleep each night to function at their best. However, the exact number of hours needed can vary from person to person. It is important to listen to your body and make sure you are getting enough sleep to feel rested and alert during the day.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 16, 'total_tokens': 74, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0dhssblfFN0Hy73cPRD4IwLG5JnZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019be34c-8f2a-7160-9759-344218bb2295-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 58, 'total_tokens': 74, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(llm.invoke("What is the sentiment of this review. Give one word answer Positive or Negative - The staff was friendly and helpful. I had a great experience with my loan officer."))

# %%
import pandas as pd

# Create a list of log messages
log_messages = [
    "INFO: Server started successfully",
    "WARNING: Low disk space",
    "CRITICAL: Database connection failed",
    "CRITICAL: Security breach detected",
    "INFO: New feature released",
]

# Create a DataFrame with 10 rows and 1 column
df = pd.DataFrame(log_messages, columns=["Message"])
df

# %%
# Classify each log message using llm.invoke
df["Sentiment"] = df["Message"].apply(lambda message: llm.invoke(f"Classify the severity of this log message make give output as CRITICAL if the message is critical: {message}"))

# %%
df

# %% [markdown]
# # Gen AI - Code Generation in Google Colab

# %% [markdown]
# Import dataset from https://raw.githubusercontent.com/giridhar276/Datasets/master/Automobile%20Data%20Set/AutoDataset.csv

# %% [markdown]
# print number of rows and columns

# %% [markdown]
# Print the column names

# %% [markdown]
# Create a bar chart for the 'fuel-type' column

# %% [markdown]
# Findout outliers in price column
